# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# This is focused on converting bounding box annotations from a traditional format into the YOLOv10 format, which is suitable for training object detection models. The original dataset contains bounding box coordinates in the format:
# ymin, ymax, xmin, xmax
# The conversion process transforms these coordinates into the YOLOv10 format:
# class_id, center_x, center_y, width, height

# %%
import pandas as pd

# Load CSV file
csv_file = '/content/Licplatesdetection_train.csv'  # Replace with your CSV file path
df = pd.read_csv(csv_file)

# Function to convert (ymin, xmin, ymax, xmax) to (center_x, center_y, width, height)
def convert_bbox(ymin, xmin, ymax, xmax):
    center_x = (xmin + xmax) / 2
    center_y = (ymin + ymax) / 2
    width = xmax - xmin
    height = ymax - ymin
    return center_x, center_y, width, height

# Define class_id (Assuming a single class, use 0 as default class_id, change if needed)
class_id = 0

# Create a new DataFrame to store the converted values
converted_data = []

for index, row in df.iterrows():
    img_id = row['img_id']
    ymin = row['ymin']
    xmin = row['xmin']
    ymax = row['ymax']
    xmax = row['xmax']

    # Convert the bounding box coordinates
    center_x, center_y, width, height = convert_bbox(ymin, xmin, ymax, xmax)

    # Append the data as a new row: [img_id, class_id, center_x, center_y, width, height]
    converted_data.append([img_id, class_id, center_x, center_y, width, height])

# Create a new DataFrame with the converted data
columns = ['img_id', 'class_id', 'center_x', 'center_y', 'width', 'height']
converted_df = pd.DataFrame(converted_data, columns=columns)

# Save the new CSV file
output_csv = 'converted_annotations.csv'  # Path to save the new CSV
converted_df.to_csv(output_csv, index=False)

print(f"Converted CSV file saved as {output_csv}")
# Out:
# Converted CSV file saved as converted_annotations.csv

# %%
# !unzip /content/Licplatesdetection_train.zip
# Out:
# Archive:  /content/Licplatesdetection_train.zip
#    creating: license_plates_detection_train/
#   inflating: license_plates_detection_train/1.jpg
#   inflating: license_plates_detection_train/2.jpg
#   inflating: license_plates_detection_train/3.jpg
#   inflating: license_plates_detection_train/4.jpg
#   inflating: license_plates_detection_train/5.jpg
#   inflating: license_plates_detection_train/6.jpg
#   inflating: license_plates_detection_train/7.jpg
#   inflating: license_plates_detection_train/8.jpg
#   inflating: license_plates_detection_train/9.jpg
#   inflating: license_plates_detection_train/10.jpg
#   inflating: license_plates_detection_train/11.jpg
#   inflating: license_plates_detection_train/12.jpg
#   inflating: license_plates_detection_train/13.jpg
#   inflating: license_plates_detection_train/14.jpg
#   inflating: license_plates_detection_train/15.jpg
#   inflating: license_plates_detection_train/16.jpg
#   inflating: license_plates_detection_train/17.jpg
#   inflating: license_plates_detection_train/18.jpg
#   inflating: license_plates_detection_train/19.jpg
#   inflating: license_plates_detection_train/20.jpg
#   inflating: license_plates_detection_train/21.jpg
#   inflating: license_plates_detection_train/22.jpg
#   inflating: license_plates_detection_train/23.jpg
#   inflating: license_plates_detection_train/24.jpg
#   inflating: license_plates_detection_train/25.jpg
#   inflating: license_plates_detection_train/26.jpg
#   inflating: license_plates_detection_train/27.jpg
#   inflating: license_plates_detection_train/28.jpg
#   inflating: license_plates_detection_train/29.jpg
#   inflating: license_plates_detection_train/30.jpg
#   inflating: license_plates_detection_train/31.jpg
#   inflating: license_plates_detection_train/32.jpg
#   inflating: license_plates_detection_train/33.jpg
#   inflating: license_plates_detection_train/459.jpg
#   inflating: license_plates_detection_train/460.jpg
#   inflating: license_plates_detection_train/461.jpg
#   inflating: license_plates_detection_train/462.jpg
#   inflating: license_plates_detection_train/463.jpg
#   inflating: license_plates_detection_train/464.jpg
#   inflating: license_plates_detection_train/465.jpg
#   inflating: license_plates_detection_train/466.jpg
#   inflating: license_plates_detection_train/467.jpg
#   inflating: license_plates_detection_train/468.jpg
#   inflating: license_plates_detection_train/469.jpg
#   inflating: license_plates_detection_train/470.jpg
#   inflating: license_plates_detection_train/471.jpg
#   inflating: license_plates_detection_train/472.jpg
#   inflating: license_plates_detection_train/473.jpg
#   inflating: license_plates_detection_train/474.jpg
#   inflating: license_plates_detection_train/475.jpg
#   inflating: license_plates_detection_train/476.jpg
#   inflating: license_plates_detection_train/477.jpg
#   inflating: license_plates_detection_train/478.jpg
#   inflating: license_plates_detection_train/479.jpg
#   inflating: license_plates_detection_train/480.jpg
#   inflating: license_plates_detection_train/481.jpg
#   inflating: license_plates_detection_train/482.jpg
#   inflating: license_plates_detection_train/483.jpg
#   inflating: license_plates_detection_train/484.jpg
#   inflating: license_plates_detection_train/485.jpg
#   inflating: license_plates_detection_train/486.jpg
#   inflating: license_plates_detection_train/487.jpg
#   inflating: license_plates_detection_train/488.jpg
#   inflating: license_plates_detection_train/489.jpg
#   inflating: license_plates_detection_train/490.jpg
#   inflating: license_plates_detection_train/491.jpg
#   inflating: license_plates_detection_train/492.jpg
#   inflating: license_plates_detection_train/493.jpg
#   inflating: license_plates_detection_train/494.jpg
#   inflating: license_plates_detection_train/495.jpg
#   inflating: license_plates_detection_train/496.jpg
#   inflating: license_plates_detection_train/497.jpg
#   inflating: license_plates_detection_train/498.jpg
#   inflating: license_plates_detection_train/499.jpg
#   inflating: license_plates_detection_train/500.jpg
#   inflating: license_plates_detection_train/501.jpg
#   inflating: license_plates_detection_train/502.jpg
#   inflating: license_plates_detection_train/503.jpg
#   inflating: license_plates_detection_train/504.jpg
#   inflating: license_plates_detection_train/505.jpg
#   inflating: license_plates_detection_train/506.jpg
#   inflating: license_plates_detection_train/507.jpg
#   inflating: license_plates_detection_train/508.jpg
#   inflating: license_plates_detection_train/509.jpg
#   inflating: license_plates_detection_train/510.jpg
#   inflating: license_plates_detection_train/511.jpg
#   inflating: license_plates_detection_train/512.jpg
#   inflating: license_plates_detection_train/513.jpg
#   inflating: license_plates_detection_train/514.jpg
#   inflating: license_plates_detection_train/515.jpg
#   inflating: license_plates_detection_train/516.jpg
#   inflating: license_plates_detection_train/517.jpg
#   inflating: license_plates_detection_train/518.jpg
#   inflating: license_plates_detection_train/519.jpg
#   inflating: license_plates_detection_train/520.jpg
#   inflating: license_plates_detection_train/521.jpg
#   inflating: license_plates_detection_train/522.jpg
#   inflating: license_plates_detection_train/523.jpg
#   inflating: license_plates_detection_train/524.jpg
#   inflating: license_plates_detection_train/525.jpg
#   inflating: license_plates_detection_train/526.jpg
#   inflating: license_plates_detection_train/527.jpg
#   inflating: license_plates_detection_train/528.jpg
#   inflating: license_plates_detection_train/529.jpg
#   inflating: license_plates_detection_train/530.jpg
#   inflating: license_plates_detection_train/531.jpg
#   inflating: license_plates_detection_train/532.jpg
#   inflating: license_plates_detection_train/533.jpg
#   inflating: license_plates_detection_train/534.jpg
#   inflating: license_plates_detection_train/535.jpg
#   inflating: license_plates_detection_train/536.jpg
#   inflating: license_plates_detection_train/537.jpg
#   inflating: license_plates_detection_train/538.jpg
#   inflating: license_plates_detection_train/539.jpg
#   inflating: license_plates_detection_train/540.jpg
#   inflating: license_plates_detection_train/541.jpg
#   inflating: license_plates_detection_train/542.jpg
#   inflating: license_plates_detection_train/543.jpg
#   inflating: license_plates_detection_train/544.jpg
#   inflating: license_plates_detection_train/545.jpg
#   inflating: license_plates_detection_train/546.jpg
#   inflating: license_plates_detection_train/547.jpg
#   inflating: license_plates_detection_train/548.jpg
#   inflating: license_plates_detection_train/549.jpg
#   inflating: license_plates_detection_train/550.jpg
#   inflating: license_plates_detection_train/551.jpg
#   inflating: license_plates_detection_train/552.jpg
#   inflating: license_plates_detection_train/553.jpg
#   inflating: license_plates_detection_train/554.jpg
#   inflating: license_plates_detection_train/555.jpg
#   inflating: license_plates_detection_train/556.jpg
#   inflating: license_plates_detection_train/557.jpg
#   inflating: license_plates_detection_train/558.jpg
#   inflating: license_plates_detection_train/559.jpg
#   inflating: license_plates_detection_train/560.jpg
#   inflating: license_plates_detection_train/561.jpg
#   inflating: license_plates_detection_train/562.jpg
#   inflating: license_plates_detection_train/563.jpg
#   inflating: license_plates_detection_train/564.jpg
#   inflating: license_plates_detection_train/565.jpg
#   inflating: license_plates_detection_train/566.jpg
#   inflating: license_plates_detection_train/567.jpg
#   inflating: license_plates_detection_train/568.jpg
#   inflating: license_plates_detection_train/569.jpg
#   inflating: license_plates_detection_train/570.jpg
#   inflating: license_plates_detection_train/571.jpg
#   inflating: license_plates_detection_train/572.jpg
#   inflating: license_plates_detection_train/573.jpg
#   inflating: license_plates_detection_train/574.jpg
#   inflating: license_plates_detection_train/575.jpg
#   inflating: license_plates_detection_train/576.jpg
#   inflating: license_plates_detection_train/577.jpg
#   inflating: license_plates_detection_train/578.jpg
#   inflating: license_plates_detection_train/579.jpg
#   inflating: license_plates_detection_train/580.jpg
#   inflating: license_plates_detection_train/581.jpg
#   inflating: license_plates_detection_train/582.jpg
#   inflating: license_plates_detection_train/583.jpg
#   inflating: license_plates_detection_train/584.jpg
#   inflating: license_plates_detection_train/585.jpg
#   inflating: license_plates_detection_train/586.jpg
#   inflating: license_plates_detection_train/587.jpg
#   inflating: license_plates_detection_train/588.jpg
#   inflating: license_plates_detection_train/589.jpg
#   inflating: license_plates_detection_train/590.jpg
#   inflating: license_plates_detection_train/591.jpg
#   inflating: license_plates_detection_train/592.jpg
#   inflating: license_plates_detection_train/593.jpg
#   inflating: license_plates_detection_train/594.jpg
#   inflating: license_plates_detection_train/595.jpg
#   inflating: license_plates_detection_train/596.jpg
#   inflating: license_plates_detection_train/597.jpg
#   inflating: license_plates_detection_train/598.jpg
#   inflating: license_plates_detection_train/599.jpg
#   inflating: license_plates_detection_train/600.jpg
#   inflating: license_plates_detection_train/672.jpg
#   inflating: license_plates_detection_train/673.jpg
#   inflating: license_plates_detection_train/674.jpg
#   inflating: license_plates_detection_train/675.jpg
#   inflating: license_plates_detection_train/676.jpg
#   inflating: license_plates_detection_train/677.jpg
#   inflating: license_plates_detection_train/678.jpg
#   inflating: license_plates_detection_train/679.jpg
#   inflating: license_plates_detection_train/680.jpg
#   inflating: license_plates_detection_train/681.jpg
#   inflating: license_plates_detection_train/682.jpg
#   inflating: license_plates_detection_train/683.jpg
#   inflating: license_plates_detection_train/684.jpg
#   inflating: license_plates_detection_train/685.jpg
#   inflating: license_plates_detection_train/686.jpg
#   inflating: license_plates_detection_train/687.jpg
#   inflating: license_plates_detection_train/688.jpg
#   inflating: license_plates_detection_train/689.jpg
#   inflating: license_plates_detection_train/690.jpg
#   inflating: license_plates_detection_train/691.jpg
#   inflating: license_plates_detection_train/692.jpg
#   inflating: license_plates_detection_train/693.jpg
#   inflating: license_plates_detection_train/694.jpg
#   inflating: license_plates_detection_train/695.jpg
#   inflating: license_plates_detection_train/696.jpg
#   inflating: license_plates_detection_train/697.jpg
#   inflating: license_plates_detection_train/698.jpg
#   inflating: license_plates_detection_train/699.jpg
#   inflating: license_plates_detection_train/700.jpg
#   inflating: license_plates_detection_train/701.jpg
#   inflating: license_plates_detection_train/702.jpg
#   inflating: license_plates_detection_train/703.jpg
#   inflating: license_plates_detection_train/704.jpg
#   inflating: license_plates_detection_train/705.jpg
#   inflating: license_plates_detection_train/706.jpg
#   inflating: license_plates_detection_train/707.jpg
#   inflating: license_plates_detection_train/708.jpg
#   inflating: license_plates_detection_train/709.jpg
#   inflating: license_plates_detection_train/710.jpg
#   inflating: license_plates_detection_train/711.jpg
#   inflating: license_plates_detection_train/712.jpg
#   inflating: license_plates_detection_train/713.jpg
#   inflating: license_plates_detection_train/714.jpg
#   inflating: license_plates_detection_train/715.jpg
#   inflating: license_plates_detection_train/716.jpg
#   inflating: license_plates_detection_train/717.jpg
#   inflating: license_plates_detection_train/718.jpg
#   inflating: license_plates_detection_train/719.jpg
#   inflating: license_plates_detection_train/720.jpg
#   inflating: license_plates_detection_train/721.jpg
#   inflating: license_plates_detection_train/722.jpg
#   inflating: license_plates_detection_train/723.jpg
#   inflating: license_plates_detection_train/724.jpg
#   inflating: license_plates_detection_train/725.jpg
#   inflating: license_plates_detection_train/726.jpg
#   inflating: license_plates_detection_train/727.jpg
#   inflating: license_plates_detection_train/728.jpg
#   inflating: license_plates_detection_train/729.jpg
#   inflating: license_plates_detection_train/730.jpg
#   inflating: license_plates_detection_train/731.jpg
#   inflating: license_plates_detection_train/732.jpg
#   inflating: license_plates_detection_train/733.jpg
#   inflating: license_plates_detection_train/734.jpg
#   inflating: license_plates_detection_train/735.jpg
#   inflating: license_plates_detection_train/736.jpg
#   inflating: license_plates_detection_train/737.jpg
#   inflating: license_plates_detection_train/738.jpg
#   inflating: license_plates_detection_train/739.jpg
#   inflating: license_plates_detection_train/740.jpg
#   inflating: license_plates_detection_train/741.jpg
#   inflating: license_plates_detection_train/742.jpg
#   inflating: license_plates_detection_train/743.jpg
#   inflating: license_plates_detection_train/744.jpg
#   inflating: license_plates_detection_train/745.jpg
#   inflating: license_plates_detection_train/746.jpg
#   inflating: license_plates_detection_train/747.jpg
#   inflating: license_plates_detection_train/748.jpg
#   inflating: license_plates_detection_train/749.jpg
#   inflating: license_plates_detection_train/750.jpg
#   inflating: license_plates_detection_train/751.jpg
#   inflating: license_plates_detection_train/752.jpg
#   inflating: license_plates_detection_train/753.jpg
#   inflating: license_plates_detection_train/754.jpg
#   inflating: license_plates_detection_train/755.jpg
#   inflating: license_plates_detection_train/756.jpg
#   inflating: license_plates_detection_train/757.jpg
#   inflating: license_plates_detection_train/758.jpg
#   inflating: license_plates_detection_train/759.jpg
#   inflating: license_plates_detection_train/760.jpg
#   inflating: license_plates_detection_train/761.jpg
#   inflating: license_plates_detection_train/762.jpg
#   inflating: license_plates_detection_train/763.jpg
#   inflating: license_plates_detection_train/764.jpg
#   inflating: license_plates_detection_train/765.jpg
#   inflating: license_plates_detection_train/766.jpg
#   inflating: license_plates_detection_train/767.jpg
#   inflating: license_plates_detection_train/768.jpg
#   inflating: license_plates_detection_train/769.jpg
#   inflating: license_plates_detection_train/770.jpg
#   inflating: license_plates_detection_train/771.jpg
#   inflating: license_plates_detection_train/772.jpg
#   inflating: license_plates_detection_train/773.jpg
#   inflating: license_plates_detection_train/774.jpg
#   inflating: license_plates_detection_train/775.jpg
#   inflating: license_plates_detection_train/776.jpg
#   inflating: license_plates_detection_train/777.jpg
#   inflating: license_plates_detection_train/778.jpg
#   inflating: license_plates_detection_train/779.jpg
#   inflating: license_plates_detection_train/780.jpg
#   inflating: license_plates_detection_train/781.jpg
#   inflating: license_plates_detection_train/782.jpg
#   inflating: license_plates_detection_train/783.jpg
#   inflating: license_plates_detection_train/784.jpg
#   inflating: license_plates_detection_train/785.jpg
#   inflating: license_plates_detection_train/786.jpg
#   inflating: license_plates_detection_train/787.jpg
#   inflating: license_plates_detection_train/788.jpg
#   inflating: license_plates_detection_train/789.jpg
#   inflating: license_plates_detection_train/790.jpg
#   inflating: license_plates_detection_train/791.jpg
#   inflating: license_plates_detection_train/792.jpg
#   inflating: license_plates_detection_train/793.jpg
#   inflating: license_plates_detection_train/794.jpg
#   inflating: license_plates_detection_train/795.jpg
#   inflating: license_plates_detection_train/796.jpg
#   inflating: license_plates_detection_train/797.jpg
#   inflating: license_plates_detection_train/798.jpg
#   inflating: license_plates_detection_train/799.jpg
#   inflating: license_plates_detection_train/800.jpg
#   inflating: license_plates_detection_train/801.jpg
#   inflating: license_plates_detection_train/802.jpg
#   inflating: license_plates_detection_train/803.jpg
#   inflating: license_plates_detection_train/804.jpg
#   inflating: license_plates_detection_train/805.jpg
#   inflating: license_plates_detection_train/806.jpg
#   inflating: license_plates_detection_train/807.jpg
#   inflating: license_plates_detection_train/808.jpg
#   inflating: license_plates_detection_train/809.jpg
#   inflating: license_plates_detection_train/810.jpg
#   inflating: license_plates_detection_train/811.jpg
#   inflating: license_plates_detection_train/812.jpg
#   inflating: license_plates_detection_train/813.jpg
#   inflating: license_plates_detection_train/814.jpg
#   inflating: license_plates_detection_train/815.jpg
#   inflating: license_plates_detection_train/816.jpg
#   inflating: license_plates_detection_train/817.jpg
#   inflating: license_plates_detection_train/818.jpg
#   inflating: license_plates_detection_train/819.jpg
#   inflating: license_plates_detection_train/820.jpg
#   inflating: license_plates_detection_train/821.jpg
#   inflating: license_plates_detection_train/822.jpg
#   inflating: license_plates_detection_train/823.jpg
#   inflating: license_plates_detection_train/824.jpg
#   inflating: license_plates_detection_train/825.jpg
#   inflating: license_plates_detection_train/826.jpg
#   inflating: license_plates_detection_train/827.jpg
#   inflating: license_plates_detection_train/828.jpg
#   inflating: license_plates_detection_train/829.jpg
#   inflating: license_plates_detection_train/830.jpg
#   inflating: license_plates_detection_train/831.jpg
#   inflating: license_plates_detection_train/832.jpg
#   inflating: license_plates_detection_train/833.jpg
#   inflating: license_plates_detection_train/834.jpg
#   inflating: license_plates_detection_train/835.jpg
#   inflating: license_plates_detection_train/836.jpg
#   inflating: license_plates_detection_train/837.jpg
#   inflating: license_plates_detection_train/838.jpg
#   inflating: license_plates_detection_train/839.jpg
#   inflating: license_plates_detection_train/840.jpg
#   inflating: license_plates_detection_train/841.jpg
#   inflating: license_plates_detection_train/842.jpg
#   inflating: license_plates_detection_train/843.jpg
#   inflating: license_plates_detection_train/844.jpg
#   inflating: license_plates_detection_train/845.jpg
#   inflating: license_plates_detection_train/846.jpg
#   inflating: license_plates_detection_train/847.jpg
#   inflating: license_plates_detection_train/848.jpg
#   inflating: license_plates_detection_train/849.jpg
#   inflating: license_plates_detection_train/850.jpg
#   inflating: license_plates_detection_train/851.jpg
#   inflating: license_plates_detection_train/852.jpg
#   inflating: license_plates_detection_train/853.jpg
#   inflating: license_plates_detection_train/854.jpg
#   inflating: license_plates_detection_train/855.jpg
#   inflating: license_plates_detection_train/856.jpg
#   inflating: license_plates_detection_train/857.jpg
#   inflating: license_plates_detection_train/858.jpg
#   inflating: license_plates_detection_train/859.jpg
#   inflating: license_plates_detection_train/860.jpg
#   inflating: license_plates_detection_train/861.jpg
#   inflating: license_plates_detection_train/862.jpg
#   inflating: license_plates_detection_train/863.jpg
#   inflating: license_plates_detection_train/864.jpg
#   inflating: license_plates_detection_train/865.jpg
#   inflating: license_plates_detection_train/866.jpg
#   inflating: license_plates_detection_train/867.jpg
#   inflating: license_plates_detection_train/868.jpg
#   inflating: license_plates_detection_train/869.jpg
#   inflating: license_plates_detection_train/870.jpg
#   inflating: license_plates_detection_train/871.jpg
#   inflating: license_plates_detection_train/872.jpg
#   inflating: license_plates_detection_train/873.jpg
#   inflating: license_plates_detection_train/874.jpg
#   inflating: license_plates_detection_train/875.jpg
#   inflating: license_plates_detection_train/876.jpg
#   inflating: license_plates_detection_train/877.jpg
#   inflating: license_plates_detection_train/878.jpg
#   inflating: license_plates_detection_train/879.jpg
#   inflating: license_plates_detection_train/880.jpg
#   inflating: license_plates_detection_train/881.jpg
#   inflating: license_plates_detection_train/882.jpg
#   inflating: license_plates_detection_train/883.jpg
#   inflating: license_plates_detection_train/884.jpg
#   inflating: license_plates_detection_train/885.jpg
#   inflating: license_plates_detection_train/886.jpg
#   inflating: license_plates_detection_train/887.jpg
#   inflating: license_plates_detection_train/888.jpg
#   inflating: license_plates_detection_train/889.jpg
#   inflating: license_plates_detection_train/890.jpg
#   inflating: license_plates_detection_train/891.jpg
#   inflating: license_plates_detection_train/892.jpg
#   inflating: license_plates_detection_train/893.jpg
#   inflating: license_plates_detection_train/894.jpg
#   inflating: license_plates_detection_train/895.jpg
#   inflating: license_plates_detection_train/896.jpg
#   inflating: license_plates_detection_train/897.jpg
#   inflating: license_plates_detection_train/898.jpg
#   inflating: license_plates_detection_train/899.jpg
#   inflating: license_plates_detection_train/900.jpg

# %% [markdown]
# This focuses on normalizing bounding box annotations for license plate detection from images. The original dataset provides bounding box coordinates, which are transformed into normalized values suitable for training object detection models, particularly in the YOLO format.
#
# The script reads bounding box annotations from a CSV file, normalizes the coordinates based on the dimensions of the respective images, and saves the normalized data into a new CSV file.

# %%
import pandas as pd
import cv2
import os

# Load the converted CSV file
csv_file = 'converted_annotations.csv'  # Replace with your CSV file path
df = pd.read_csv(csv_file)

# Define the images folder
images_folder = '/content/license_plates_detection_train'  # Replace with your images folder path

# Function to normalize the bounding box values
def normalize_bbox(center_x, center_y, width, height, img_width, img_height):
    norm_center_x = center_x / img_width
    norm_center_y = center_y / img_height
    norm_width = width / img_width
    norm_height = height / img_height
    return norm_center_x, norm_center_y, norm_width, norm_height

# List to store normalized data
normalized_data = []

# Group the CSV by img_id so we can process all bounding boxes for a single image
grouped = df.groupby('img_id')

# Loop through each image in the CSV
for img_id, group in grouped:
    # Get the path of the image
    image_path = os.path.join(images_folder, img_id)

    # Load the image to get its dimensions
    img = cv2.imread(image_path)
    if img is None:
        print(f"Image not found: {image_path}")
        continue

    img_height, img_width, _ = img.shape

    # Get the bounding box values for this image and normalize them
    for _, row in group.iterrows():
        class_id = row['class_id']
        center_x = row['center_x']
        center_y = row['center_y']
        width = row['width']
        height = row['height']

        # Normalize the bounding box values
        norm_center_x, norm_center_y, norm_width, norm_height = normalize_bbox(center_x, center_y, width, height, img_width, img_height)

        # Append normalized values
        normalized_data.append([img_id, class_id, norm_center_x, norm_center_y, norm_width, norm_height])

# Create a DataFrame for normalized data and save to a new CSV file
normalized_columns = ['img_id', 'class_id', 'norm_center_x', 'norm_center_y', 'norm_width', 'norm_height']
normalized_df = pd.DataFrame(normalized_data, columns=normalized_columns)
normalized_df.to_csv('normalized_annotations.csv', index=False)

print("Normalized CSV file saved as 'normalized_annotations.csv'")
# Out:
# Normalized CSV file saved as 'normalized_annotations.csv'

# %% [markdown]
# This  aims to prepare a custom dataset for license plate recognition by normalizing bounding box annotations and organizing images and labels into training and validation sets. The dataset is structured in a way compatible with YOLO (You Only Look Once) object detection models.

# %%
import os
import shutil
import pandas as pd
import cv2
from sklearn.model_selection import train_test_split

# Load the original CSV file
csv_file = 'converted_annotations.csv'  # Replace with your original CSV file path
df = pd.read_csv(csv_file)

# Define the images folder
images_folder = '/content/license_plates_detection_train'

# Define the target directory for the dataset
output_dir = 'custom_dataset'  # The base directory for train and validation folders
train_folder = os.path.join(output_dir, 'train')
val_folder = os.path.join(output_dir, 'validation')

# Create the directory structure if it doesn't exist
for folder in [train_folder, val_folder]:
    os.makedirs(os.path.join(folder, 'images'), exist_ok=True)
    os.makedirs(os.path.join(folder, 'labels'), exist_ok=True)

# Function to normalize the bounding box values
def normalize_bbox(center_x, center_y, width, height, img_width, img_height):
    norm_center_x = center_x / img_width
    norm_center_y = center_y / img_height
    norm_width = width / img_width
    norm_height = height / img_height
    return norm_center_x, norm_center_y, norm_width, norm_height

# Function to save labels to a text file in the required format
def save_label_file(image_name, bboxes, folder):
    label_path = os.path.join(folder, 'labels', f'{image_name}.txt')
    with open(label_path, 'w') as f:
        for bbox in bboxes:
            class_id, norm_center_x, norm_center_y, norm_width, norm_height = bbox
            # Write the normalized bbox values to the file
            f.write(f'{class_id} {norm_center_x} {norm_center_y} {norm_width} {norm_height}\n')

# Function to copy images to the correct folder
def copy_image(image_name, src_folder, dst_folder):
    src_image_path = os.path.join(src_folder, image_name)
    dst_image_path = os.path.join(dst_folder, 'images', image_name)
    shutil.copyfile(src_image_path, dst_image_path)

# Helper function to process data
def process_data(dataframe, src_images_folder, target_folder):
    grouped = dataframe.groupby('img_id')

    for img_id, group in grouped:
        # Load the image to get its dimensions
        image_path = os.path.join(src_images_folder, img_id)
        img = cv2.imread(image_path)
        if img is None:
            print(f"Image not found: {image_path}")
            continue

        img_height, img_width, _ = img.shape

        # Get the bounding box values for the image and normalize them
        bboxes = []
        for _, row in group.iterrows():
            class_id = row['class_id']
            center_x = row['center_x']
            center_y = row['center_y']
            width = row['width']
            height = row['height']

            # Normalize the bounding box values
            norm_center_x, norm_center_y, norm_width, norm_height = normalize_bbox(center_x, center_y, width, height, img_width, img_height)

            # Append normalized values
            bboxes.append([class_id, norm_center_x, norm_center_y, norm_width, norm_height])

        # Copy the image to the appropriate folder (train or validation)
        copy_image(img_id, src_images_folder, target_folder)
        # Save the labels in the .txt file with the image name
        save_label_file(img_id.split('.')[0], bboxes, target_folder)

# Split data into train and validation (80% train, 20% validation)
train_df, val_df = train_test_split(df, test_size=0.2, random_state=42)

# Process the train data
process_data(train_df, images_folder, train_folder)

# Process the validation data
process_data(val_df, images_folder, val_folder)

print("Dataset directory structure created successfully.")
# Out:
# Dataset directory structure created successfully.

# %%
import os
import zipfile

def zip_folder(folder_path, output_zip_path):
    # Create a ZipFile object
    with zipfile.ZipFile(output_zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
        # Walk through the folder
        for root, _, files in os.walk(folder_path):
            for file in files:
                # Create a relative path for the file in the zip
                file_path = os.path.join(root, file)
                zipf.write(file_path, os.path.relpath(file_path, os.path.join(folder_path, '..')))

# Specify the folder you want to zip and the output zip file name
folder_to_zip = '/content/custom_dataset'  # Replace with your folder path
output_zip_file = 'dataset.zip'  # Desired output zip file name

# Call the function to zip the folder
zip_folder(folder_to_zip, output_zip_file)

print(f"Folder '{folder_to_zip}' zipped as '{output_zip_file}'")
# Out:
# Folder '/content/custom_dataset' zipped as 'dataset.zip'
